# %% [markdown]
# <a href="https://colab.research.google.com/github/kowshii27-rbg/Trading-bot/blob/main/trading_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install python-binance
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 45.8 MB/s eta 0:00:00
# ...

# %%
from binance.client import Client
import time

# %%
client = Client(API_KEY,API_SECRET,testnet=True)
client.get_account()
# Out:
# {'makerCommission': 0,
#  'takerCommission': 0,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'commissionRates': {'maker': '0.00000000',
#   'taker': '0.00000000',
#   'buyer': '0.00000000',
#   'seller': '0.00000000'},
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'brokered': False,
#  'requireSelfTradePrevention': False,
#  'preventSor': False,
#  'updateTime': 1735982279955,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'ETH', 'free': '1.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTC', 'free': '1.00200000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '7.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '1.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '9806.40400100', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '3090.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '983.00000000', 'locked': '0.00000000'},
# ...

# %%
API_KEY = 'ObbYOCBwDB1xNg2h4ZVSqJsnQNwD9Ja77L1Yz7eQhOG80M51SMBeN0xrPgWb67Oy'
API_SECRET = 'GKxkVrRYsTQlUXkmb5ibiWujAZXNkW2HQCPU1xJMubXOJkj1MCPzwva8g1jJ7k8B'

Client = Client(API_KEY,API_SECRET,testnet=True)
Client.get_account()

symbol = 'BTCUSDT'
buy_price_threshold = 97866
sell_price_threshold = 97850
trade_quantity = 0.002

def get_current_price(symbol):
    ticker = Client.get_symbol_ticker(symbol=symbol)
    return float(ticker['price'])

get_current_price(symbol)
# Out:
# 97862.3

# %%
def place_buy_order(symbol,quantity):
  order = client.order_market_buy(symbol=symbol,quantity = quantity)
  print(f"Buy order done : {order}")

# %%
place_buy_order(symbol,trade_quantity)
# Out:
# Buy order done : {'symbol': 'BTCUSDT', 'orderId': 23178984, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJf0309aea69ab09f2ba8597', 'transactTime': 1735982779821, 'price': '0.00000000', 'origQty': '0.00200000', 'executedQty': '0.00200000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '195.72460000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1735982779821, 'fills': [{'price': '97862.30000000', 'qty': '0.00023000', 'commission': '0.00000000', 'commissionAsset': 'BTC', 'tradeId': 6414970}, {'price': '97862.30000000', 'qty': '0.00177000', 'commission': '0.00000000', 'commissionAsset': 'BTC', 'tradeId': 6414971}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}

# %%
def place_sell_order(symbol,quantity):
  order = client.order_market_sell(symbol=symbol,quantity = quantity)
  print(f"sell order done : {order}")

# %%
place_sell_order(symbol,trade_quantity)
# Out:
# sell order done : {'symbol': 'BTCUSDT', 'orderId': 23179012, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJf9480d791ae3d588230a35', 'transactTime': 1735982784155, 'price': '0.00000000', 'origQty': '0.00200000', 'executedQty': '0.00200000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '195.72458000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'SELL', 'workingTime': 1735982784155, 'fills': [{'price': '97862.29000000', 'qty': '0.00200000', 'commission': '0.00000000', 'commissionAsset': 'USDT', 'tradeId': 6414980}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}

# %%
def trading_bot():
  in_position = False

  while True:
    current_price = get_current_price(symbol)
    print(f"current price of {symbol}: {current_price}")

    if not in_position:
      if current_price < buy_price_threshold:
        print(f"price is slow {buy_price_threshold}.placing buy order.")
        place_buy_order(symbol,trade_quantity)
        in_position = True
    else:
      if current_price > sell_price_threshold:
        print(f"price is above {sell_price_threshold}.placing sell order.")
        place_sell_order(symbol,trade_quantity)
        in_position = False


time.sleep(3)

# %%
if __name__ == "__main__":
  trading_bot()
# Out:
# current price of BTCUSDT: 97862.29
# price is slow 97866.placing buy order.
# Buy order done : {'symbol': 'BTCUSDT', 'orderId': 23179099, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJ1e61294d90ddd3e6d46693', 'transactTime': 1735982794068, 'price': '0.00000000', 'origQty': '0.00200000', 'executedQty': '0.00200000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '195.72603620', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1735982794068, 'fills': [{'price': '97862.32000000', 'qty': '0.00021000', 'commission': '0.00000000', 'commissionAsset': 'BTC', 'tradeId': 6414994}, {'price': '97863.10000000', 'qty': '0.00179000', 'commission': '0.00000000', 'commissionAsset': 'BTC', 'tradeId': 6414995}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}
# current price of BTCUSDT: 97863.1
# price is above 97850.placing sell order.
# ...
